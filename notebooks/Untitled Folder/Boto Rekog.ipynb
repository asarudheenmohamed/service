# %%
import boto3

sourceFile='/Users/varunpasad/Desktop/photos/2014.jpg'
targetFile='/Users/varunpasad/Desktop/photos/2016.jpg'

import base64

with open(sourceFile, "rb") as image_file:
    sourceFile = image_file.read()
with open(targetFile, "rb") as image_file:
    targetFile = image_file.read()

client=boto3.client(
    'rekognition',
    'us-east-1',
    aws_access_key_id="AKIAJFBOS7T6DUXS2ZJA",
    aws_secret_access_key="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",
)

response=client.compare_faces(SimilarityThreshold=70,
                              SourceImage={'Bytes':sourceFile},
                              TargetImage={'Bytes':targetFile}
                             )
# print (response)

# for faceMatch in response['FaceMatches']:
#     position = faceMatch['Face']['BoundingBox']
#     confidence = str(faceMatch['Face']['Confidence'])
#     print('The face at ' +
#            str(position['Left']) + ' ' +
#            str(position['Top']) +
#            ' matches with ' + confidence + '% confidence')
import pprint
targetFile
# Out:
# '\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x02\x01\x01,\x01,\x00\x00\xff\xe1\x15\xb0Exif\x00\x00II*\x00\x08\x00\x00\x00\n\x00\x0f\x01\x02\x00\x06\x00\x00\x00\x86\x00\x00\x00\x10\x01\x02\x00\x0f\x00\x00\x00\x8c\x00\x00\x00\x12\x01\x03\x00\x01\x00\x00\x00\x01\x00\x00\x00\x1a\x01\x05\x00\x01\x00\x00\x00\x9b\x00\x00\x00\x1b\x01\x05\x00\x01\x00\x00\x00\xa3\x00\x00\x00(\x01\x03\x00\x01\x00\x00\x00\x02\x00\x00\x001\x01\x02\x00\x1c\x00\x00\x00\xab\x00\x00\x002\x01\x02\x00\x14\x00\x00\x00\xc7\x00\x00\x00\x13\x02\x03\x00\x01\x00\x00\x00\x02\x00\x00\x00i\x87\x04\x00\x01\x00\x00\x00\xdc\x00\x00\x00\xdc\x03\x00\x00Canon\x00Canon EOS 550D\x00\xc0\xc6-\x00\x10\'\x00\x00\xc0\xc6-\x00\x10\'\x00\x00Adobe Photoshop CS3 Windows\x002015:12:16 12:45:12\x00\x00\x1e\x00\x9a\x82\x05\x00\x01\x00\x00\x00J\x02\x00\x00\x9d\x82\x05\x00\x01\x00\x00\x00R\x02\x00\x00"\x88\x03\x00\x01\x00\x00\x00\x01\x00\x00\x00\'\x88\x03\x00\x01\x00\x00\x00d\x00\x00\x00\x00\x90\x07\x00\x04\x00\x00\x000221\x03\x90\x02\x00\x14\x00\x00\x00Z
# ...

# %%
# client.detect_labels(Image={'Bytes': sourceFile})
# Out:
# {u'Labels': [{u'Confidence': 99.29410552978516, u'Name': u'Human'},
#   {u'Confidence': 99.2940902709961, u'Name': u'People'},
#   {u'Confidence': 99.29410552978516, u'Name': u'Person'},
#   {u'Confidence': 57.475685119628906, u'Name': u'Face'},
#   {u'Confidence': 54.25965881347656, u'Name': u'Portrait'},
#   {u'Confidence': 50.500858306884766, u'Name': u'Female'}],
#  'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#    'content-length': '306',
#    'content-type': 'application/x-amz-json-1.1',
#    'date': 'Tue, 30 Jan 2018 02:19:51 GMT',
#    'x-amzn-requestid': '0c7b0f3d-0564-11e8-ad65-5d28867680e9'},
#   'HTTPStatusCode': 200,
#   'RequestId': '0c7b0f3d-0564-11e8-ad65-5d28867680e9',
#   'RetryAttempts': 0}}

# %% [markdown]
# # Initial Onboarding

# %%
client.create_collection(CollectionId="tendercuts-erp-employee")
records = env['hr.employee'].search([('image', '!=', False)])
client.index_faces(CollectionId='tendercuts-erp-employee', DetectionAttributes=["DEFAULT"], ExternalImageId=str(records[0].id), Image={"Bytes": base64.b64decode(records[0].image)})
# Out:
# {u'CollectionArn': u'aws:rekognition:us-east-1:186008207309:collection/tendercuts-erp-employee',
#  u'FaceModelVersion': u'2.0',
#  'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#    'content-length': '135',
#    'content-type': 'application/x-amz-json-1.1',
#    'date': 'Tue, 20 Mar 2018 04:45:35 GMT',
#    'x-amzn-requestid': '87c166c4-2bf9-11e8-b1e6-6370bc7c2e56'},
#   'HTTPStatusCode': 200,
#   'RequestId': '87c166c4-2bf9-11e8-b1e6-6370bc7c2e56',
#   'RetryAttempts': 0},
#  u'StatusCode': 200}

# %%
client.search_faces_by_image(CollectionId="tendercuts-erp-employee", FaceMatchThreshold=90, Image={"Bytes":targetFile}, MaxFaces=1)
# Out:
# {u'FaceMatches': [{u'Face': {u'BoundingBox': {u'Height': 0.41259899735450745,
#      u'Left': 0.20674200356006622,
#      u'Top': 0.22907699644565582,
#      u'Width': 0.5904269814491272},
#     u'Confidence': 99.99919891357422,
#     u'ExternalImageId': u'1',
#     u'FaceId': u'816d4120-9b35-4bb4-b8ce-9f29eb28489a',
#     u'ImageId': u'df2c38fa-c704-50d1-8ba7-76bc233b037d'},
#    u'Similarity': 99.97075653076172}],
#  u'FaceModelVersion': u'2.0',
#  'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#    'content-length': '538',
#    'content-type': 'application/x-amz-json-1.1',
#    'date': 'Tue, 20 Mar 2018 05:20:13 GMT',
#    'x-amzn-requestid': '5d061f8e-2bfe-11e8-a6de-55dea4cbaf3b'},
#   'HTTPStatusCode': 200,
#   'RequestId': '5d061f8e-2bfe-11e8-a6de-55dea4cbaf3b',
#   'RetryAttempts': 0},
#  u'SearchedFaceBoundingBox': {u'Height': 0.45052874088287354,
#   u'Left': 0.21233004331588745,
#   u'Top': 0.17528611421585083,
#   u'Width': 0.5773887038230896},
# ...
